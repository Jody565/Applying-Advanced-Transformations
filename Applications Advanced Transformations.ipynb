# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os,json

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##Load the Superhero Data

# %% [markdown]
# df_super = pd.read_csv('Data/superhero_info.csv')
# df_super.head()

# %%
df_super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Gender        463 non-null    object
#  1   Race          463 non-null    object
#  2   Alignment     463 non-null    object
#  3   Hair color    463 non-null    object
#  4   Eye color     463 non-null    object
#  5   Skin color    463 non-null    object
#  6   Measurements  463 non-null    object
#  7   Hero          463 non-null    object
#  8   Publisher     463 non-null    object
# dtypes: object(9)
# memory usage: 32.7+ KB

# %% [markdown]
# ##Clean the Data

# %%
df_super.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates in the dataset

# %%
df_super.isna().sum()
# Out:
# Hero|Publisher    0
# Gender            0
# Race              0
# Alignment         0
# Hair color        0
# Eye color         0
# Skin color        0
# Measurements      0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset

# %% [markdown]
# ###Split the Hero/Publisher fields into two Columns

# %%
df_super['Hero|Publisher'].head(2)
# Out:
# 0            A-Bomb|Marvel Comics
# 1    Abe Sapien|Dark Horse Comics
# Name: Hero|Publisher, dtype: object

# %%
df_super[['Hero','Publisher']] = df_super['Hero|Publisher'].str.split('|',expand=True)
df_super.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
df_super = df_super.drop(columns=['Hero|Publisher'])
df_super.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %% [markdown]
# ###Split then Measurement field into two Columns

# %%
measurements = df_super.loc[0,"Measurements"]
print(type(measurements))
measurements
# Out:
# <class 'str'>
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
measurements = measurements.replace("'",'"')
measurements
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
fixed_measurements = json.loads(measurements)
print(type(fixed_measurements))
fixed_measurements
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
## use .str.replace to replace all single quotes
df_super['Measurements'] = df_super['Measurements'].str.replace("'",'"')
## Apply the json.loads to the full column
df_super['Measurements'] = df_super['Measurements'].apply(json.loads)
df_super['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
test_measurements = df_super.loc[0, 'Measurements']
print(type(test_measurements))
test_measurements
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
Height_Weight = df_super['Measurements'].apply(pd.Series)
Height_Weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# concat Height_Weight with original dataframe
df_super = pd.concat((df_super, Height_Weight), axis = 1)
df_super.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
df_super = df_super.drop(columns=['Measurements'])

# %%
df_super.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %% [markdown]
# ###Convert Height and Weight to Numeric DataType

# %%
df_super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    object
#  9   Weight      463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %%
df_super.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
to_replace = [' ', 'cm']

# %%
# run a loop to replace all of the empty spaces in the list at once
for char in to_replace:
    df_super['Height'] = df_super['Height'].str.replace(char, '', regex=False)
df_super.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height    Weight
# 0         A-Bomb      Marvel Comics  203.0  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0 kg
# 2       Abin Sur          DC Comics  185.0   90.0 kg
# 3    Abomination      Marvel Comics  203.0  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0  122.0 kg

# %%
df_super['Height'] = df_super['Height'].astype('float')
type(df_super['Height'][0])
# Out:
# numpy.float64

# %%
df_super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    float64
#  9   Weight      463 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 36.3+ KB

# %%
to_replace = [' ', 'kg']

# %%
for char in to_replace:
    df_super['Weight'] = df_super['Weight'].str.replace(char, '', regex=False)
df_super.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height Weight
# 0         A-Bomb      Marvel Comics   203.0  441.0
# 1     Abe Sapien  Dark Horse Comics   191.0   65.0
# 2       Abin Sur          DC Comics   185.0   90.0
# 3    Abomination      Marvel Comics   203.0  441.0
# 4  Absorbing Man      Marvel Comics   193.0  122.0

# %%
df_super['Weight'] = df_super['Weight'].astype('float')
type(df_super['Weight'][0])
# Out:
# numpy.float64

# %%
df_super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    float64
#  9   Weight      463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %% [markdown]
# ##Load the Superhero Powers

# %%
df_power = pd.read_csv('Data/superhero_powers.csv')
df_power.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# ###Seperate Powers into different Columns

# %%
test_powers = df_power.loc[2,'Powers']
print(type(test_powers))
test_powers
# Out:
# <class 'str'>
# 'Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner'

# %%
## adding expand=True
df_power['Powers_Split'] = df_power['Powers'].str.split(',')

# %%
df_power.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_Split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
print(type(df_power['Powers_Split'][0]))
# Out:
# <class 'list'>

# %% [markdown]
# ###Create One Hot Encoderd Columns

# %%
exploded = df_power.explode('Powers_Split')
exploded.head()
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Powers_Split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
## saving the unique values from the exploded column
cols_to_make = exploded['Powers_Split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in cols_to_make:
    df_power[col] = df_power['Powers'].str.contains(col)
df_power.head()
# Out:
# C:\Users\om93405\AppData\Local\Temp\ipykernel_7040\2901467257.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_power[col] = df_power['Powers'].str.contains(col)
# C:\Users\om93405\AppData\Local\Temp\ipykernel_7040\2901467257.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_power[col] = df_power['Powers'].str.contains(col)
# ...

# %%
df_power = df_power.drop(columns=['Powers','Powers_Split'])

# %%
df_power.head()
# Out:
#     hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# ...

# %% [markdown]
# ##Combine Dataframes

# %%
## merge 2 dataframes
merged = pd.merge(df_super, df_power, left_on='Hero', right_on='hero_names')
merged.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2       Abin Sur          DC Comics   185.0    90.0  ...           False
# 3    Abomination      Marvel Comics   203.0   441.0  ...           False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %% [markdown]
# ###Compare the average weight of super powers who have Super Speed to those who do not.

# %%
data = merged[['Hero', 'Super Speed']]

# %%
data.head()
# Out:
#             Hero  Super Speed
# 0         A-Bomb        False
# 1     Abe Sapien        False
# 2       Abin Sur        False
# 3    Abomination         True
# 4  Absorbing Man        False

# %%
heroes_speed = merged['Super Speed'] == True
df_speed = merged[heroes_speed]
df_speed
# Out:
#      Gender               Race Alignment Hair color Eye color Skin color  \
# 3      Male  Human / Radiation       bad    No Hair     green    Unknown
# 5      Male              Human      good      Blond      blue    Unknown
# 8      Male            Unknown       bad      White      blue    Unknown
# 9      Male             Cyborg       bad      Black     brown    Unknown
# 10     Male            Unknown      good      Blond      blue    Unknown
# ..      ...                ...       ...        ...       ...        ...
# 453  Female           Demi-God      good      Blond      blue    Unknown
# 454    Male            Unknown      good      Black       red    Unknown
# 455  Female             Amazon      good      Black      blue    Unknown
# 460    Male     Yoda's species      good      White     brown      green
# 462    Male            Unknown       bad      Brown       red    Unknown
#
#              Hero      Publisher  Height  Weight  ... Weather Control  \
# ...

# %%
no_speed = merged[~heroes_speed]
no_speed
# Out:
#      Gender            Race Alignment        Hair color Eye color Skin color  \
# 0      Male           Human      good           No Hair    yellow    Unknown
# 1      Male   Icthyo Sapien      good           No Hair      blue       blue
# 2      Male         Ungaran      good           No Hair      blue        red
# 4      Male           Human       bad           No Hair      blue    Unknown
# 6      Male           Human      good             Brown     brown    Unknown
# ..      ...             ...       ...               ...       ...        ...
# 456  Female  Mutant / Clone      good             Black     green    Unknown
# 457    Male         Unknown      good             Brown      blue    Unknown
# 458    Male           Human      good             Blond      blue    Unknown
# 459  Female           Human      good  Strawberry Blond      blue    Unknown
# 461  Female           Human      good             Black      blue    Unknown
#
# ...

# %%
# Average weight of heroes with Super Speed and heroes without Super Speed
avg_speedWeight = df_speed['Weight'].mean().round(2)
avg_noSpeedWeight = no_speed['Weight'].mean().round(2)
print(f'The average weight for Super Heroes that have "Super Speed" is {avg_speedWeight}.')
print(f'The average weight for Super Heroes that do not have "Super Speed" is {avg_noSpeedWeight}.')
# Out:
# The average weight for Super Heroes that have "Super Speed" is 129.4.
# The average weight for Super Heroes that do not have "Super Speed" is 101.77.

# %% [markdown]
# ### What is the Average height of heroes for each Publisher?

# %%
data2 = merged[['Publisher', 'Height']]

# %%
data2.head()
# Out:
#            Publisher  Height
# 0      Marvel Comics   203.0
# 1  Dark Horse Comics   191.0
# 2          DC Comics   185.0
# 3      Marvel Comics   203.0
# 4      Marvel Comics   193.0

# %%
publisher_height = merged.groupby('Publisher')['Height'].mean()
publisher_height
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64
